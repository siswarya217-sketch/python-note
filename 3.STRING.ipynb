# %% [markdown]
# <font size="5"> STRING </font>

# %%
print('hi')

# %%
k="hi how are you ,i am fine"
print(k)

# %% [markdown]
# ## Multiline string

# %%
k=""" Late at night, Emma found an old, 
    dusty key hidden under a loose floorboard.
    Curiosity led her to the attic, 
    where she discovered a locked chest that seemed to hum with energy. 
    As she turned the key, the chest creaked open, 
    revealing a portal to a world she never imagined."""

print(k)
# Out:
#  Late at night, Emma found an old,
#     dusty key hidden under a loose floorboard.
#     Curiosity led her to the attic,
#     where she discovered a locked chest that seemed to hum with energy.
#     As she turned the key, the chest creaked open,
#     revealing a portal to a world she never imagined.

# %% [markdown]
# ## string length

# %%
k="hi how are you"
print(len(k))
# Out:
# 14

# %% [markdown]
# ## string indexing

# %%
b = "Hello,  World!"
print(b[-4])
# Out:
# r

# %%
b = "Hello, World!"
print(b[-4])

# %% [markdown]
# ## string slicing

# %%
b = "welcome, besant!"
print(b[-7:-1])
# Out:
# besant

# %%
b="python"
b[1:]

# %%
b = "Hello, World!"
print(b[2:])
# Out:
# elc

# %%
b = "Hello, World!"
print(b[:6])

# %%
b = "Hello, World!"
print(b[7:12])
print(b[-6:-1])

# %%
b = "welcome, World!"
print(b[-5:-2])

# %%
b = "Hello, World!"
print(b[-5:])

# %% [markdown]
# ## string modify

# %%
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
a = "heLlo, World!"
print(a.capitalize())
# Out:
# Hello, world!

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %%
a = "    Hello, World!    "
print(a)
print(a.strip())
# Out:
#     Hello, World!
# Hello, World!

# %%
a = "    Hello, World!    "
b=a.strip()
print(len(a))
print(len(b))
print(b)
# Out:
# 21
# 13
# Hello, World!

# %%
a= "Hello,World"
print(a.split("W"))
# Out:
# ['Hello,', 'orld']

# %%
a="hi  hello"
print(a.split())

# %%
a = "Hello, World!"
print(a[0])
b=a.split()
print(b[0])

# %%
a=input("enter your name")
b=input("enter your place")


k=f"i am {a} from {b}"
print(k)
# Out:
# enter your name ajcbac
# enter your place uhaoc
# i am ajcbac from uhaoc

# %%
name=input("enter your name")
native=input("enter your native")

out=f"hi i am {name},from {native}"
print(out)
