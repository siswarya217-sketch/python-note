# %% [markdown]
# ## DATA TYPES

# %% [markdown]
# ## text type

# %%
#STRING 

k="@##$$%%%^8999"
print(type(k))
# Out:
# <class 'str'>

# %% [markdown]
# ## numeric type

# %%
#integer

k=5
print(type(k))
# Out:
# <class 'int'>

# %%
#float

k=5.079
print(type(k))
# Out:
# <class 'float'>

# %%
# complex

k=1+2j
print(type(k))
# Out:
# <class 'complex'>

# %% [markdown]
# ## Casting

# %%
k=7
# Out:
# 7

# %%
k=float(4)
k
# Out:
# 4.0

# %%
k=complex(4)
k
# Out:
# (4+0j)

# %%
k=str(4)
print(str(4))
# Out:
# 4

# %%
k=1+289j
print(k.real)
print(k.imag)
# Out:
# 1.0
# 289.0

# %%
k=7.8
k1=int(k)
k2=str(k)
k3=complex(k)
print(k1)
print(k2)
print(k3)
# Out:
# 89
# 89.0
# (89+0j)

# %%
k=float(input("enter the number"))
print(type(k))
print(k)
# Out:
# enter the number 868
# <class 'float'>
# 868.0

# %%
k=int(7.8)

# %%
k1=str(k)

# %%
k2=int(k)
print(k2)
# Out:
# 7

# %%
k="7"
